# %% [markdown]
# File này phân tích 2 biến với nhau, chủ yếu là feature với price.
#
# Nội dung:
#
# - living vs price
# - bed vs price
# - bath vs price
# - income vs price
# - rent vs price
# - risk_overall vs price
# - dist_city vs price
# - home_type vs price
#
# Mục đích:
#
# Xem biến nào có vẻ liên quan đến giá nhà.
