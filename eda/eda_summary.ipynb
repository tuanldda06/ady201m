# %% [markdown]
# 06_eda_summary.ipynb
#
# File này tổng kết EDA.
#
# Nội dung:
#
# - Dataset có sạch không
# - Price có bị lệch không
# - Biến nào liên quan mạnh tới price
# - Có outlier không
# - Có cần log transform không
# - Những feature nào nên dùng cho model
#
# Mục đích:
#
# Viết kết luận trước khi chuyển sang Machine Learning.
