# %% [markdown]
# Tổng quan về dữ liệu
# Nội dung:
#
# - Import thư viện
# - Đọc zillow_final.csv
# - Xem df.head()
# - Xem df.shape
# - Xem df.info()
# - Xem df.describe()
# - Kiểm tra tên cột
#
# Mục đích:
#
# Hiểu dataset có bao nhiêu dòng, bao nhiêu cột, biến nào là số, biến nào là categorical.
