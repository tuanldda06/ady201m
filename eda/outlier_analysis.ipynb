# %% [markdown]
# File này chỉ xử lý outlier.
#
# Nội dung:
#
# - Outlier của price
# - Outlier của living
# - Outlier của lot_sqft
# - Outlier của bed, bath
# - So sánh trước/sau log transform
#
# Mục đích:
#
# Kiểm tra những giá trị quá lớn hoặc bất thường có thể ảnh hưởng tới model.
