# %% [markdown]
# File này phân tích nhiều biến cùng lúc.
#
# Nội dung:
#
# - Correlation heatmap
# - Top correlation với price
# - Price theo home_type và income_group
# - Price theo risk_group và distance_group
#
# Mục đích:
#
# Hiểu mối quan hệ phức tạp hơn giữa nhiều feature và giá nhà.
