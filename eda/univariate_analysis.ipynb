# %% [markdown]
# File này phân tích từng biến một.
#
# Nội dung:
#
# - Phân phối price
# - Phân phối log(price)
# - Phân phối bed, bath, living, lot_sqft
# - Count từng loại nhà
# - Histogram các biến số
# - Boxplot các biến quan trọng
#
# Mục đích:
#
# Xem từng biến có phân phối như thế nào, có lệch không, có giá trị bất thường không.
