# %% [markdown]
# 1.SET UP

# %%
import sys
assert sys.version_info >= (3, 5)


import warnings
warnings.filterwarnings('ignore')

import sklearn
assert sklearn.__version__ >= "0.20"

# import thư viện
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# 2. DATA CLEANING

# %%
df = pd.read_csv(('../data_csv/zillow_full_raw.csv'),sep=',',on_bad_lines='skip',  engine="python")
df.head()
# Out:
#            zpid              palsId rawHomeStatusCd  \
# 0  2.073568e+09   17327010_26844339         ForSale
# 1  1.987515e+07  31493001_226002630         ForSale
# 2  2.053261e+07   17327010_26846711         ForSale
# 3           NaN                 NaN             NaN
# 4  2.093480e+07   17327006_26843895         ForSale
#
#   marketingStatusSimplifiedCd  \
# 0           For Sale by Agent
# 1           For Sale by Agent
# 2           For Sale by Agent
# 3                         NaN
# 4           For Sale by Agent
#
#                                               imgSrc hasImage  \
# 0  https://photos.zillowstatic.com/fp/baa91158903...     True
# 1  https://photos.zillowstatic.com/fp/60873898547...     True
# 2  https://photos.zillowstatic.com/fp/8d2b3e54fc2...     True
# 3  https://photos.zillowstatic.com/fp/07b915b7231...     True
# 4  https://photos.zillowstatic.com/fp/f95fee73996...     True
#
#                                            detailUrl statusType  \
# 0  /homedetails/8721-W-Sunset-Plaza-Ter-West-Holl...   FOR_SALE
# 1  /homedetails/23649-Aetna-St-Woodland-Hills-CA-...   FOR_SALE
# 2  /homedetails/2350-Benedict-Canyon-Dr-Beverly-H...   FOR_SALE
# 3             /b/645-w-9th-st-los-angeles-ca-CkBBCq/   FOR_SALE
# 4  /homedetails/1161-W-67th-St-Los-Angeles-CA-900...   FOR_SALE
#
#                    statusText          price  ...  \
# 0              House for sale     $4,980,000  ...
# 1              House for sale     $1,215,000  ...
# 2              House for sale     $2,629,000  ...
# 3                    For Rent  From $389,000  ...
# 4  Multi-family home for sale       $400,000  ...
#
#   nearest_city_san_francisco.1 nearest_city_san_jose.1 nearest_city_nan.1  \
# 0                        False                   False              False
# 1                        False                   False              False
# 2                        False                   False              False
# 3                        False                   False              False
# 4                        False                   False              False
#
#    nearest_airport_LAX.1  nearest_airport_OAK.1  nearest_airport_SAN.1  \
# 0                   True                  False                  False
# 1                   True                  False                  False
# 2                   True                  False                  False
# 3                   True                  False                  False
# 4                   True                  False                  False
#
#    nearest_airport_SFO.1 nearest_airport_SJC.1 nearest_airport_SMF.1  \
# 0                  False                 False                 False
# 1                  False                 False                 False
# 2                  False                 False                 False
# 3                  False                 False                 False
# 4                  False                 False                 False
#
#   nearest_airport_nan.1
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
#
# [5 rows x 227 columns]

# %%
# Số lượng data
len(df)
# Out:
# 5757

# %%
nan_value = float("NaN")
df.replace("0", nan_value, inplace=True)
# Thống kê  tỷ lệ phần trăm giá trị null trong các cột
(df.isnull().sum() / df.isnull().count()).sort_values(ascending=False)
# Out:
# plid                     1.000000
# buildingName             1.000000
# isBuilding               0.999826
# minBaths                 0.999826
# minArea                  0.999826
#                            ...
# nearest_airport_SAN.1    0.000000
# nearest_airport_SFO.1    0.000000
# nearest_airport_SJC.1    0.000000
# nearest_airport_SMF.1    0.000000
# nearest_airport_nan.1    0.000000
# Length: 227, dtype: float64

# %%
#Đổi tất cả giá trị -1 thành NaN
df.replace(-1, np.nan, inplace=True)
# Out:
#               zpid              palsId rawHomeStatusCd  \
# 0     2.073568e+09   17327010_26844339         ForSale
# 1     1.987515e+07  31493001_226002630         ForSale
# 2     2.053261e+07   17327010_26846711         ForSale
# 3              NaN                 NaN             NaN
# 4     2.093480e+07   17327006_26843895         ForSale
# ...            ...                 ...             ...
# 5752  9.958096e+07     3006_NDP2602025         ForSale
# 5753  1.658097e+07  32383001_198504152         ForSale
# 5754  4.598090e+08     3006_OC26010908         ForSale
# 5755  4.591146e+08     3006_IV25277668         ForSale
# 5756  2.105217e+09     3006_OC26032454         ForSale
#
#      marketingStatusSimplifiedCd  \
# 0              For Sale by Agent
# 1              For Sale by Agent
# 2              For Sale by Agent
# 3                            NaN
# 4              For Sale by Agent
# ...                          ...
# 5752           For Sale by Agent
# 5753           For Sale by Agent
# 5754           For Sale by Agent
# 5755           For Sale by Agent
# 5756           For Sale by Agent
#
#                                                  imgSrc hasImage  \
# 0     https://photos.zillowstatic.com/fp/baa91158903...     True
# 1     https://photos.zillowstatic.com/fp/60873898547...     True
# 2     https://photos.zillowstatic.com/fp/8d2b3e54fc2...     True
# 3     https://photos.zillowstatic.com/fp/07b915b7231...     True
# 4     https://photos.zillowstatic.com/fp/f95fee73996...     True
# ...                                                 ...      ...
# 5752  https://photos.zillowstatic.com/fp/a746c572b68...     True
# 5753  https://photos.zillowstatic.com/fp/232369444e8...     True
# 5754  https://photos.zillowstatic.com/fp/e6c8116b305...     True
# 5755  https://photos.zillowstatic.com/fp/e503be36a13...     True
# 5756  https://photos.zillowstatic.com/fp/8d5c01d3457...     True
#
#                                               detailUrl statusType  \
# 0     /homedetails/8721-W-Sunset-Plaza-Ter-West-Holl...   FOR_SALE
# 1     /homedetails/23649-Aetna-St-Woodland-Hills-CA-...   FOR_SALE
# 2     /homedetails/2350-Benedict-Canyon-Dr-Beverly-H...   FOR_SALE
# 3                /b/645-w-9th-st-los-angeles-ca-CkBBCq/   FOR_SALE
# 4     /homedetails/1161-W-67th-St-Los-Angeles-CA-900...   FOR_SALE
# ...                                                 ...        ...
# 5752  /homedetails/1432-Buena-St-Oceanside-CA-92058/...   FOR_SALE
# 5753  /homedetails/1330-Bush-St-Oceanside-CA-92058/1...   FOR_SALE
# 5754  /homedetails/1330-Bush-St-LOT-24-Oceanside-CA-...   FOR_SALE
# 5755  /homedetails/0-Capistrano-Dr-LOT-289-Oceanside...   FOR_SALE
# 5756  /homedetails/0-Benet-Rd-Oceanside-CA-92058/210...   FOR_SALE
#
#                       statusText          price  ...  \
# 0                 House for sale     $4,980,000  ...
# 1                 House for sale     $1,215,000  ...
# 2                 House for sale     $2,629,000  ...
# 3                       For Rent  From $389,000  ...
# 4     Multi-family home for sale       $400,000  ...
# ...                          ...            ...  ...
# 5752         Lot / Land for sale       $650,000  ...
# 5753         Lot / Land for sale       $649,000  ...
# 5754         Lot / Land for sale       $649,000  ...
# 5755         Lot / Land for sale     $2,500,000  ...
# 5756         Lot / Land for sale     $2,300,000  ...
#
#      nearest_city_san_francisco.1 nearest_city_san_jose.1 nearest_city_nan.1  \
# 0                           False                   False              False
# 1                           False                   False              False
# 2                           False                   False              False
# 3                           False                   False              False
# 4                           False                   False              False
# ...                           ...                     ...                ...
# 5752                        False                   False              False
# 5753                        False                   False              False
# 5754                        False                   False              False
# 5755                        False                   False              False
# 5756                        False                   False              False
#
#       nearest_airport_LAX.1  nearest_airport_OAK.1  nearest_airport_SAN.1  \
# 0                      True                  False                  False
# 1                      True                  False                  False
# 2                      True                  False                  False
# 3                      True                  False                  False
# 4                      True                  False                  False
# ...                     ...                    ...                    ...
# 5752                  False                  False                   True
# 5753                  False                  False                   True
# 5754                  False                  False                   True
# 5755                  False                  False                   True
# 5756                  False                  False                   True
#
#       nearest_airport_SFO.1 nearest_airport_SJC.1 nearest_airport_SMF.1  \
# 0                     False                 False                 False
# 1                     False                 False                 False
# 2                     False                 False                 False
# 3                     False                 False                 False
# 4                     False                 False                 False
# ...                     ...                   ...                   ...
# 5752                  False                 False                 False
# 5753                  False                 False                 False
# 5754                  False                 False                 False
# 5755                  False                 False                 False
# 5756                  False                 False                 False
#
#      nearest_airport_nan.1
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 5752                 False
# 5753                 False
# 5754                 False
# 5755                 False
# 5756                 False
#
# [5757 rows x 227 columns]

# %%
# Drop cột null > 50%
thresh = len(df) * 0.5
df.dropna(thresh = thresh, axis = 1, inplace = True)

# %%
#Xóa các cột có giá trị giống hệt nhau
df = df.loc[:, ~df.T.duplicated()]

# %%
#Xem phần trăm dữ liệu bị missing còn lại
(df.isnull().sum() / df.isnull().count()).sort_values(ascending=False)
# Out:
# zestimate_to_price_ratio      0.330554
# hdpData.homeInfo.zestimate    0.326038
# lot_to_living_ratio           0.291124
# brokerName                    0.229807
# contentType                   0.216780
#                                 ...
# nearest_airport_SFO           0.000000
# nearest_airport_SJC           0.000000
# nearest_airport_SMF           0.000000
# osm_lat_grid                  0.000000
# osm_lon_grid                  0.000000
# Length: 118, dtype: float64

# %%
df.columns
# Out:
# Index(['zpid', 'palsId', 'rawHomeStatusCd', 'marketingStatusSimplifiedCd',
#        'imgSrc', 'hasImage', 'detailUrl', 'statusType', 'statusText', 'price',
#        ...
#        'nearest_city_san_diego', 'nearest_city_san_francisco',
#        'nearest_city_san_jose', 'nearest_airport_LAX', 'nearest_airport_OAK',
#        'nearest_airport_SFO', 'nearest_airport_SJC', 'nearest_airport_SMF',
#        'osm_lat_grid', 'osm_lon_grid'],
#       dtype='str', length=118)

# %%
len(df.columns)
# Out:
# 118

# %%
df["target_price"] = pd.to_numeric(
    df["hdpData.homeInfo.price"],
    errors="coerce"
)

# %%
# Chuẩn hóa living area về sqft

df["living_area_sqft"] = pd.to_numeric(
    df["area"],
    errors="coerce"
)

#  Chuẩn hóa lot về sqft

lot_value = pd.to_numeric(
    df["hdpData.homeInfo.lotAreaValue"],
    errors="coerce"
)

lot_unit = df["hdpData.homeInfo.lotAreaUnit"].astype(str).str.lower()

df["lot_area_sqft"] = np.where(
    lot_unit.str.contains("acre", na=False),
    lot_value * 43560,
    lot_value
)

# %%
df["lot_to_living_ratio"] = (
    df["lot_area_sqft"] / df["living_area_sqft"].replace(0, np.nan)
)

df["beds_per_bath"] = (
    pd.to_numeric(df["beds"], errors="coerce")
    / pd.to_numeric(df["baths"], errors="coerce").replace(0, np.nan)
)

# %%
# Chọn cột bằng tên gốc trong file
keep_cols = [
    # Target
    "target_price",

    # Basic house features
    "beds",
    "baths",
    "area",
    "lot_area_sqft",
    "lot_to_living_ratio",
    "beds_per_bath",

    # Home type one-hot
    "home_type_CONDO",
    "home_type_LOT",
    "home_type_MANUFACTURED",
    "home_type_MULTI_FAMILY",
    "home_type_SINGLE_FAMILY",
    "home_type_TOWNHOUSE",

    # Location coordinates
    "latLong.latitude",
    "latLong.longitude",

    # Socioeconomic features
    "median_household_income",
    "poverty_rate",
    "unemployment_rate",
    "population",
    "bachelor_or_higher_rate",
    "median_gross_rent",
    "owner_occupied_rate",
    "population_density_per_km2",

    # Risk features
    "nri_overall_risk_score",
    "nri_expected_annual_loss_score",
    "nri_social_vulnerability_score",
    "nri_resilience_score",
    "wildfire_risk_score",
    "earthquake_risk_score",
    "heatwave_risk_score",

    # Distance features
    "distance_to_nearest_major_ca_city_km",
    "distance_to_nearest_major_ca_airport_km",
    "distance_to_ca_coast_approx_km",
]

# 2. Chỉ giữ cột nào thật sự tồn tại trong df
keep_cols = [col for col in keep_cols if col in df.columns]

# 3. Tạo df_model trước
df_model = df[keep_cols].copy()

# 4. Rename
rename_map = {
    "target_price": "price",

    "beds": "bed",
    "baths": "bath",
    "area": "living",
    "lot_area_sqft": "lot_a",
    "lot_to_living_ratio": "lot_living",
    "beds_per_bath": "bed_bath",

    "home_type_CONDO": "type_condo",
    "home_type_LOT": "type_lot",
    "home_type_MANUFACTURED": "type_manufactured",
    "home_type_MULTI_FAMILY": "type_multi",
    "home_type_SINGLE_FAMILY": "type_single",
    "home_type_TOWNHOUSE": "type_townhouse",

    "latLong.latitude": "lat",
    "latLong.longitude": "long",

    "median_household_income": "income",
    "poverty_rate": "poverty",
    "unemployment_rate": "unemployment",
    "population": "pop",
    "bachelor_or_higher_rate": "bachelor",
    "median_gross_rent": "rent",
    "owner_occupied_rate": "owner_occ",
    "population_density_per_km2": "pop_density",

    "nri_overall_risk_score": "risk_overall",
    "nri_expected_annual_loss_score": "risk_loss",
    "nri_social_vulnerability_score": "risk_social",
    "nri_resilience_score": "risk_resilience",
    "wildfire_risk_score": "risk_fire",
    "earthquake_risk_score": "risk_earthquake",
    "heatwave_risk_score": "risk_heat",

    "distance_to_nearest_major_ca_city_km": "dist_city",
    "distance_to_nearest_major_ca_airport_km": "dist_airport",
    "distance_to_ca_coast_approx_km": "dist_coast",
}

df_model.rename(columns=rename_map, inplace=True)

# 5. Kiểm tra kết quả
print("Shape:", df_model.shape)
print(df_model.columns.tolist())
# Out:
# Shape: (5757, 33)
# ['price', 'bed', 'bath', 'living', 'lot_a', 'lot_living', 'bed_bath', 'type_condo', 'type_lot', 'type_manufactured', 'type_multi', 'type_single', 'type_townhouse', 'lat', 'long', 'income', 'poverty', 'unemployment', 'pop', 'bachelor', 'rent', 'owner_occ', 'pop_density', 'risk_overall', 'risk_loss', 'risk_social', 'risk_resilience', 'risk_fire', 'risk_earthquake', 'risk_heat', 'dist_city', 'dist_airport', 'dist_coast']

# %%
# 6. Lưu file
df_model.to_csv("../data_csv/zillow_clean.csv", index=False, encoding="utf-8-sig")
